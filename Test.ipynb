# %% [markdown]
# <a href="https://colab.research.google.com/github/Bezzmozzg/test/blob/master/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install plotly==4.9.0

# %%
# !pip install psycopg2

# %%
import pandas as pd
import psycopg2
import plotly
pd.options.plotting.backend = "plotly"

dbname='d6qfh4tmk9h4t2'
username='xqhkevexwktfkk'
pwd='cb8c1a6070ebed38248446e0960ffe7b3fd8ea4927c0aa3ef4d7e1b630588b3f'
host='ec2-34-225-162-157.compute-1.amazonaws.com'
port='5432'

INDEX_COL = "id"
DATE_COL = "date"
BIZDEV_COL = "bizdev"


conn = psycopg2.connect("host='{}' port={} dbname='{}' user={} password={}".format(host, port, dbname, username, pwd))
sql = "SELECT * FROM b_khalutornykh;"
df = pd.read_sql_query(sql, conn, index_col=INDEX_COL)
conn = None

def real_to_percent(r):
  return [int((v/sum(r))*100) for v in r]

bizdev_productivity = df.groupby([DATE_COL, BIZDEV_COL]).size().unstack().fillna(0).apply(real_to_percent, axis=1, result_type='broadcast')

fig = bizdev_productivity.plot(
    title="Bizdev productivity table", template="simple_white", 
    labels=dict(index="date", value="percent", variable="bizdev"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e1374c58-c30c-458d-8938-07df775be533" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e1374c58-c30c-458d-8938-07df775be533")) {
#                     Plotly.newPlot(
#                         'e1374c58-c30c-458d-8938-07df775be533',
# ...
